# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train= pd.read_csv('train.csv')
test= pd.read_csv('test.csv')

# %%
col=['Id','PoolQC', 'MiscFeature', 'Alley',
     'Fence', 'FireplaceQu','Utilities','Street',
    'RoofMatl', 'Heating']
train.drop(col, axis=1, inplace=True)
test.drop(col, axis=1, inplace=True)

# %%
sns.histplot(data= train, x='SalePrice')
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# # Utilities

# %%
train['Utilities'].value_counts()
# Out:
# AllPub    1167
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
sns.countplot(data= train, x='Utilities')
# Out:
# <AxesSubplot:xlabel='Utilities', ylabel='count'>

# %% [markdown]
# # Street

# %%
train['Street'].value_counts()
# Out:
# Pave    1164
# Grvl       4
# Name: Street, dtype: int64

# %%
sns.countplot(data= train, x='Street')
# Out:
# <AxesSubplot:xlabel='Street', ylabel='count'>

# %% [markdown]
# # RoofStyle

# %%
train['RoofStyle'].value_counts()
# Out:
# Gable      913
# Hip        229
# Flat        11
# Gambrel      9
# Mansard      4
# Shed         2
# Name: RoofStyle, dtype: int64

# %%
sns.countplot(data= train, x='RoofStyle')
# Out:
# <AxesSubplot:xlabel='RoofStyle', ylabel='count'>

# %%
sns.boxplot(data=train, x='RoofStyle', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='RoofStyle', ylabel='SalePrice'>

# %% [markdown]
# # Roof Material

# %%
train['RoofMatl'].value_counts()
# Out:
# CompShg    1148
# Tar&Grv       9
# WdShngl       4
# WdShake       3
# ClyTile       1
# Metal         1
# Roll          1
# Membran       1
# Name: RoofMatl, dtype: int64

# %%
sns.countplot(data= train, x='RoofMatl')
# Out:
# <AxesSubplot:xlabel='RoofMatl', ylabel='count'>

# %% [markdown]
# # Heating

# %%
train['Heating'].value_counts()
# Out:
# GasA     1144
# GasW       12
# Grav        5
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64

# %%
sns.countplot(data= train, x='Heating')
# Out:
# <AxesSubplot:xlabel='Heating', ylabel='count'>

# %%
sns.boxplot(data=train, x='Heating', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Heating', ylabel='SalePrice'>

# %% [markdown]
# #  Heating quality and Condition

# %%
train['HeatingQC'].value_counts()
# Out:
# Ex    612
# TA    323
# Gd    196
# Fa     36
# Po      1
# Name: HeatingQC, dtype: int64

# %%
sns.countplot(data= train, x='HeatingQC')
# Out:
# <AxesSubplot:xlabel='HeatingQC', ylabel='count'>

# %%
sns.boxplot(data=train, x='HeatingQC', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='HeatingQC', ylabel='SalePrice'>

# %% [markdown]
# # CentralAir

# %%
train['CentralAir'].value_counts()
# Out:
# Y    1092
# N      76
# Name: CentralAir, dtype: int64

# %%
sns.countplot(data= train, x='CentralAir')
# Out:
# <AxesSubplot:xlabel='CentralAir', ylabel='count'>

# %%
sns.boxplot(data=train, x='CentralAir', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='CentralAir', ylabel='SalePrice'>

# %% [markdown]
# # Electrical

# %%
sns.countplot(data= train, x='Electrical')
# Out:
# <AxesSubplot:xlabel='Electrical', ylabel='count'>

# %%
sns.boxplot(data=train, x='Electrical', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Electrical', ylabel='SalePrice'>

# %% [markdown]
# # Home functionality

# %%
train['Functional'].value_counts()
# Out:
# Typ     1090
# Min2      28
# Min1      23
# Mod       14
# Maj1       9
# Maj2       3
# Sev        1
# Name: Functional, dtype: int64

# %%
sns.countplot(data= train, x='Functional')
# Out:
# <AxesSubplot:xlabel='Functional', ylabel='count'>

# %%
sns.boxplot(data=train, x='Functional', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Functional', ylabel='SalePrice'>

# %% [markdown]
# # Conditions

# %% [markdown]
# Condition1: Proximity to various conditions
#
# Condition2: Proximity to various conditions (if more than one is present)

# %%
train['Condition1'].value_counts()
# Out:
# Norm      1008
# Feedr       67
# Artery      36
# RRAn        19
# PosN        16
# RRAe         9
# PosA         7
# RRNn         4
# RRNe         2
# Name: Condition1, dtype: int64

# %%
train['Condition2'].value_counts()
# Out:
# Norm      1156
# Feedr        4
# RRNn         2
# PosN         2
# PosA         1
# Artery       1
# RRAn         1
# RRAe         1
# Name: Condition2, dtype: int64

# %%
fig, ax = plt.subplots(nrows=1,ncols=2 , figsize=(15,5)) 
sns.countplot(data= train, x='Condition1',ax=ax[0])
sns.countplot(data= train, x='Condition2',ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Condition2', ylabel='count'>

# %%
fig, ax = plt.subplots(nrows=1,ncols=2 , figsize=(15,5)) 
sns.boxplot(data=train, x='Condition1', y='SalePrice', ax=ax[0])
sns.boxplot(data=train, x='Condition2', y='SalePrice', ax=ax[1])
# Out:
# <AxesSubplot:xlabel='Condition2', ylabel='SalePrice'>

# %% [markdown]
# # Garage features

# %%
train['GarageType']=train['GarageType'].fillna('NA')

# %%
train['GarageType'].value_counts()
# Out:
# Attchd     698
# Detchd     307
# BuiltIn     70
# Basment     12
# 2Types       6
# CarPort      6
# Name: GarageType, dtype: int64

# %%
sns.countplot(data= train, x='GarageType')
# Out:
# <AxesSubplot:xlabel='GarageType', ylabel='count'>

# %%
sns.boxplot(data=train, x='GarageType', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageType', ylabel='SalePrice'>

# %%
sns.boxplot(data=train, x='GarageType', y='GarageType')
sns.countplot(data= train, x='GarageType')
train['GarageType'].value_counts()

# %%
# useless columns lets drop them 
col=['Utilities', 'Street','RoofMatl','Heating']
train.drop(col, axis=1, inplace=True)
test.drop(col, axis=1, inplace=True)

# %% [markdown]
# # MSSubClass

# %%
train['MSSubClass'].value_counts()
# Out:
# 20     439
# 60     232
# 50     112
# 120     70
# 160     56
# 30      53
# 80      50
# 70      45
# 90      38
# 190     27
# 85      15
# 75      11
# 45       9
# 180      8
# 40       3
# Name: MSSubClass, dtype: int64

# %% [markdown]
# Categorical features contains 15 categories

# %%
train['MSSubClass']=train['MSSubClass'].astype('category')

# %%
train['MSSubClass'].cat.as_ordered()
# Out:
# 0        20
# 1        20
# 2        20
# 3        20
# 4        50
#        ...
# 1163    120
# 1164     60
# 1165     60
# 1166     20
# 1167    180
# Name: MSSubClass, Length: 1168, dtype: category
# Categories (15, int64): [20 < 30 < 40 < 45 ... 120 < 160 < 180 < 190]

# %%
sns.histplot(data= train, x='MSSubClass',)

# %%
plt.figure(figsize=(10,8))
sns.histplot(data= train, x='MSSubClass',)
plt.xticks(train['MSSubClass'].value_counts().index)
# Out:
# ([<matplotlib.axis.XTick at 0x1888005e400>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#plt.figure(figsize=(20,15))
sns.pairplot(train, y_vars=train.columns.values, x_vars="MSSubClass",size=5)
# Out:
# C:\Users\Zeina Abu Ruqaia\anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.scatterplot(data=train,x='MSSubClass', y='SalePrice')
plt.xticks(train['MSSubClass'].value_counts().index)
# Out:
# ([<matplotlib.axis.XTick at 0x188fd9935e0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
train[train['Utilities']=='NoSeWa']
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 312          20       RL          NaN    14375   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 312         Lvl    NoSeWa   CulDSac  ...        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 312       0      1    2009       COD        Abnorml     137500
#
# [1 rows x 80 columns]
